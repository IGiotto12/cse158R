# %%
import gzip
import json
import csv

# %%
def readGz(path):
    for l in gzip.open(path, 'rt'):
        yield eval(l)

# %%
def readCSV(path):
    f = gzip.open(path, 'rt')
    f.readline()
    for l in f:
        b,u,r,t = l.strip().split(',')
        r = int(r)
        yield b,u,r,t

# %%
allRatings = []
for l in readCSV("rating-Alaska.csv.gz"):
    allRatings.append(l)

allRatings
# Out:
# [('0x56b646ed2220b77f:0xd8975e316de80952',
#   '109129804842686204152',
#   5,
#   '1566331951619'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '108233908345184666082',
#   5,
#   '1503373018846'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '112719098184283195565',
#   5,
#   '1410062370985'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '111423891190453074451',
#   5,
#   '1495241580499'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '113240926405758965692',
#   5,
#   '1504917982385'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '113044837891141253355',
#   4,
#   '1474765901185'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '105889967148147311402',
#   5,
#   '1499178889954'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '110329155147592031570',
#   4,
#   '1472858535682'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '108989634908602011119',
#   5,
#   '1529649811341'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '115962574912569482669',
#   1,
#   '1565638584279'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '107776308656137082130',
#   5,
#   '1461267716241'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '105002979785465574951',
#   5,
#   '1529681946388'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '106400304907549423087',
#   3,
#   '1501376415787'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '114928451379442250967',
#   3,
#   '1494884912688'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '115738865548796071801',
#   5,
#   '1466170294782'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '104402954145391808582',
#   5,
#   '1529087964079'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '101176993332282615693',
#   5,
#   '1506174365844'),
#  ('0x56b646ed2220b77f:0xd8975e316de80952',
#   '108242439686915933772',
#   5,
#   '1500774004605'),
#  ('0x56c8992b5dee7225:0x9f7f4bf151868cf7',
#   '116393231987956549910',
#   5,
#   '1625369270215'),
#  ('0x56c8992b5dee7225:0x9f7f4bf151868cf7',
#   '115383646362808743390',
#   3,
#   '1627071932904'),
#  ('0x56c8992b5dee7225:0x9f7f4bf151868cf7',
#   '117985992059356012741',
#   4,
#   '1629350418882'),
#  ('0x56c8992b5dee7225:0x9f7f4bf151868cf7',
#   '110378874048030559829',
#   5,
#   '1628220637856'),
#  ('0x56c8992b5dee7225:0x9f7f4bf151868cf7',
#   '100423398473578523442',
#   4,
#   '1630997923825'),
#  ('0x56c8992b5dee7225:0x9f7f4bf151868cf7',
#   5,
#   '1561354203946'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '114918570498584490238',
#   5,
#   '1498857438311'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '101174494850534459771',
#   5,
#   '1506094000650'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '108956132254752217411',
#   5,
#   '1478038945789'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '110000358816139925941',
#   3,
#   '1502450096410'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '116702840455401228477',
#   5,
#   '1444788197745'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '108132985484403700427',
#   4,
#   '1549377638264'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '109877772311899726268',
#   5,
#   '1607575395299'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '117500539438530148854',
#   5,
#   '1502495758123'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '103157427071160965296',
#   2,
#   '1483609617482'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '115664349673182595677',
#   5,
#   '1608689957536'),
#  ('0x5400df82e4ca2741:0x5c72dfc793b3cdfc',
#   '105982445849414704064',
#   5,
#   '1565114230395'),
#  ('0x54011e1f313d46b3:0x63671effe038577d',
#   '108956132254752217411',
#   5,
#   '1478030670895'),
#  ('0x54011e1f313d46b3:0x63671effe038577d',
#   '101650331441285878014',
#   5,
#   '1596240220617'),
#  ('0x54011e1f313d46b3:0x63671effe038577d',
#   '117056883296790018081',
#   5,
#   '1501778543438'),
#  ('0x54011e1f313d46b3:0x63671effe038577d',
#   '111336699096705029294',
#   2,
#   '1496947342053'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '113908593641188678191',
#   3,
#   '1623993048860'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '117241290097326417173',
#   5,
#   '1579198565251'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '112223655477517148889',
#   5,
#   '1533412617284'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '114327589204819650406',
#   5,
#   '1534449782306'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '110970296139955146800',
#   5,
#   '1528955812454'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '107876482920243958231',
#   5,
#   '1534885456787'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '117790520026358368567',
#   5,
#   '1452835697655'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '115952534696397849681',
#   5,
#   '1500452850922'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '101656108528077517144',
#   5,
#   '1522088092072'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '109031737657668817657',
#   4,
#   '1494004932702'),
#  ('0x5400df8320a87e6b:0x828a01cf6015dbf1',
#   '1630025184412'),
#  ('0x56c92174187ea6d9:0x92c0419e974b35e6',
#   '111757350039056201571',
#   5,
#   '1630024501902'),
#  ('0x883b2d3aad6d04c1:0xef73961dcb1dd41',
#   '108939598038201321863',
#   1,
#   '1594214383583'),
#  ('0x56c895e84962a447:0x855143df7c886cf0',
#   '108933588641054959623',
#   5,
#   '1609986988770'),
#  ('0x56c895e84962a447:0x855143df7c886cf0',
#   '110117639454039516255',
#   5,
#   '1581550314602'),
#  ('0x56c895e84962a447:0x855143df7c886cf0',
#   '112582401795711552180',
#   5,
#   '1627977896986'),
#  ('0x56c895e84962a447:0x855143df7c886cf0',
#   '110144954290189829594',
#   5,
#   '1624309711334'),
#  ('0x56c897ac7cd0c4f3:0xf53fbc7eb571e3f4',
#   '108933588641054959623',
#   5,
#   '1617494305206'),
#  ('0x56c897ac7cd0c4f3:0xf53fbc7eb571e3f4',
#   '116307716402885430549',
#   3,
#   '1618176259016'),
#  ('0x56c897ac7cd0c4f3:0xf53fbc7eb571e3f4',
#   '110646757737610557279',
#   5,
#   '1602303640843'),
#  ('0x56c897ac7cd0c4f3:0xf53fbc7eb571e3f4',
#   '112125710470338623701',
#   4,
#   '1602178259820'),
#  ('0x56c897ac7cd0c4f3:0xf53fbc7eb571e3f4',
#   '114350811189402192420',
#   5,
#   '1591196301759'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '112408467552252080949',
#   5,
#   '1535817478554'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '103236145697920805423',
#   5,
#   '1621992566033'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '108825753816657898347',
#   5,
#   '1603405037904'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '102307820173158076239',
#   5,
#   '1565411746594'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '108932936840826135269',
#   5,
#   '1584600312818'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '108239076646478729541',
#   5,
#   '1558551844347'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '115752829904951288660',
#   5,
#   '1552679290775'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '105603972123581016121',
#   5,
#   '1537402301693'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '111721386989916901191',
#   5,
#   '1500280287463'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '110625113863435743865',
#   5,
#   '1529602134754'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '112581194819427433453',
#   5,
#   '1570842602170'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '113565426728260009650',
#   5,
#   '1539586728847'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '116215090823995578280',
#   5,
#   '1622781686119'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '112733053966586746240',
#   5,
#   '1620435946548'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '111838710353450277141',
#   5,
#   '1583017973730'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '117352598332704829623',
#   5,
#   '1601678922851'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '100157067358898583495',
#   5,
#   '1561906449454'),
#  ('0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec',
#   '116988076772120004041',
#   5,
#   '1539729927769'),
#  ('0x56c12d9331100c9b:0x1928f20e7115f388',
#   '103997686592798206003',
#   5,
#   '1625355483800'),
#  ('0x56c12d9331100c9b:0x1928f20e7115f388',
#   '112234733094044234799',
#   5,
#   '1525454787845'),
#  ('0x56c12d9331100c9b:0x1928f20e7115f388',
#   '108932936840826135269',
#   5,
#   '1544310826627'),
#  ('0x57abb1463ddfbbe7:0x463e7cc5218a77ed',
#   '100075787340127946905',
#   5,
#   '1630725673467'),
#  ('0x57abb1463ddfbbe7:0x463e7cc5218a77ed',
#   '110876622532828253086',
#   5,
#   '1473455052220'),
#  ('0x57abb1463ddfbbe7:0x463e7cc5218a77ed',
#   '101199031568105897446',
#   3,
#   '1461722010744'),
#  ('0x57abb1463ddfbbe7:0x463e7cc5218a77ed',
#   '105759922068175775696',
#   5,
#   '1530715755125'),
#  ('0x57abb1463ddfbbe7:0x463e7cc5218a77ed',
#   '110612178195932268675',
#   5,
#   '1492352791078'),
#  ('0x57abb1463ddfbbe7:0x463e7cc5218a77ed',
#   '108925660190949774577',
#   5,
#   '1496688504049'),
#  ('0x57abb12c85c1034f:0x2aa2a7a1ac207833',
#   '110912599030967501432',
#   5,
#   '1623912984114'),
#  ('0x57abb12c85c1034f:0x2aa2a7a1ac207833',
#   '111397915684097079116',
#   5,
#   '1551498140908'),
#  ('0x57abb12c85c1034f:0x2aa2a7a1ac207833',
#   '102500030870881962666',
#   4,
#   '1558051738858'),
#  ('0x57abb12c85c1034f:0x2aa2a7a1ac207833',
#   '118006101600073434867',
#   5,
#   '1537648967863'),
#  ('0x57abb12c85c1034f:0x2aa2a7a1ac207833',
#   '101099708129091045375',
#   5,
#   '1478823102295'),
#  ('0x57abb12c85c1034f:0x2aa2a7a1ac207833',
#   '108925660190949774577',
#   5,
#   '1496717705779'),
#  ('0x57abb12c85c1034f:0x2aa2a7a1ac207833',
#   '100212959695588058833',
#   3,
#   '1552873959269'),
#  ('0x57abb12c85c1034f:0x2aa2a7a1ac207833',
#   '114702380499660352840',
#   5,
#   '1558144753289'),
#  ('0x56c89b5db9237529:0xc75ab400a9511ba2',
#   '108925024482067883352',
#   5,
#   '1558077576516'),
#  ('0x56c8750c2f5ada35:0xa16ccbe76a56fbb9',
#   '114413596564141765014',
#   5,
#   '1620976495530'),
#  ('0x56c8750c2f5ada35:0xa16ccbe76a56fbb9',
#   '108925024482067883352',
#   5,
#   '1629073396023'),
#  ('0x56c8a2c08577f80f:0xccf5ca6f6f96a508',
#   '116068133599267050378',
#   5,
#   '1620818705818'),
#  ('0x56c8a2c08577f80f:0xccf5ca6f6f96a508',
#   '108925024482067883352',
#   1,
#   '1602955637880'),
#  ('0x56c8a2c08577f80f:0xccf5ca6f6f96a508',
#   '103042893154168526363',
#   1,
#   '1491504365632'),
#  ('0x56c8a2c08577f80f:0xccf5ca6f6f96a508',
#   '114436378165487119093',
#   1,
#   '1560823541554'),
#  ('0x56c8a2c08577f80f:0xccf5ca6f6f96a508',
#   '118009636973514949883',
#   5,
#   '1384972533329'),
#  ('0x56c8a2c08577f80f:0xccf5ca6f6f96a508',
#   '100634151952245511697',
#   5,
#   '1541001559705'),
#  ('0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3',
#   '108925024482067883352',
#   5,
#   '1622934352342'),
#  ('0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3',
#   '113928054885307774676',
#   5,
#   '1550747718757'),
#  ('0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3',
),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '106407910906803766142',
#   5,
#   '1537933775920'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '113850652675987495303',
#   5,
#   '1459384269171'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '112176831226106150779',
#   1,
#   '1490900996486'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '116749414316813015654',
#   5,
#   '1556664437716'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '110016364401980948497',
#   5,
#   '1570330782199'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '111999004743702468207',
#   5,
#   '1541720256448'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '104518812729570251568',
#   5,
#   '1576031863308'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '113100211437854676986',
#   5,
#   '1492641247212'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '118210883868558887696',
#   5,
#   '1471546106835'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '114676985444811655894',
#   5,
#   '1556842846633'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '111040909045646191560',
#   5,
#   '1557348157557'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '108402554818114143228',
#   5,
#   '1539293609118'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '105875081567649622095',
#   5,
#   '1568925438960'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '104089220700313843576',
#   5,
#   '1559095815706'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '101838166781886053683',
#   5,
#   '1553626457043'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '107791211603307507137',
#   5,
#   '1564513472177'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '112977269879797804310',
#   5,
#   '1557344957983'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '114293528007942435883',
#   5,
#   '1567130053959'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '116428937327572251002',
#   5,
#   '1475604260009'),
#  ('0x56c896914b819ae7:0xdd3ee2efe145476b',
#   '115795112432833765699',
#   5,
#   '1611037581777'),
#  ...]

# %% [markdown]
# ### JSON TO CSV

# %%
input_file = 'review-Alaska_10.json'
output_file = 'review-Alaska_10.csv'

with open(output_file, 'w', encoding='utf-8', newline='') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    with open(input_file, 'r', encoding='utf-8') as json_file:
        first_line = True
        for line in json_file:
            json_object = json.loads(line.strip())
            
            if first_line:
                csv_writer.writerow(json_object.keys())
                first_line = False
            
            csv_writer.writerow(json_object.values())

print(f"Data successfully converted to {output_file}")
# Out:
# Data successfully converted to review-Alaska_10.csv

# %%
input_file = 'review-Alaska_10.json'

with open(input_file, 'r', encoding='utf-8') as json_file:
    data = [json.loads(line.strip()) for line in json_file]

# %%
data
# Out:
# [{'user_id': '109129804842686204152',
#   'name': 'Nicki Gore',
#   'time': 1566331951619,
#   'rating': 5,
#   'text': 'We always stay here when in Valdez for silver salmon fishing. The elderly couple that run it are amazing to talk to, extremely helpful. The campsites are very well maintained.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56b646ed2220b77f:0xd8975e316de80952'},
#  {'user_id': '113240926405758965692',
#   'name': 'Allen Ratliff',
#   'time': 1504917982385,
#   'rating': 5,
#   'text': 'Great campground for the price. Nice hot unlimited showers, laundy, and  spacious wooded lots. Full hook ups. Late check in available.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56b646ed2220b77f:0xd8975e316de80952'},
#  {'user_id': '113044837891141253355',
#   'name': 'Jonathan Tringali',
#   'time': 1474765901185,
#   'rating': 4,
#   'text': "We tent camped here for 2 nights while exploring Valdez. The center of the campground was in the open and there are treed sites around the edges. Don't expect lower foliage separating the sites. Still this is much nicer than the other RV parking lots in town which seemed wide open.\n\nThere is a bath house with 1 set of coin operated washer/dryer, 2 restrooms (sink toilet) and 2 shower rooms (sink, toilet, shower). The hot water will run out after a few showers. They provide floor mats towels for you to use which is nice, but they lack vent fans to remove moisture so it is prone to mold.\n\nWi-Fi didn't reach our site on the back edge of the campground. Overall we were happy with our stay at this campground and would stay there again.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56b646ed2220b77f:0xd8975e316de80952'},
#  {'user_id': '110329155147592031570',
#   'name': 'S Blad',
#   'time': 1472858535682,
#   'rating': 4,
#   'text': "This place is just a few miles outside Valdez, which I thought was a bonus.  It was surrounded by woods and had some trees throughout the park for shade.  The bathrooms were clean and the showers were nice.  The dump station was a little underwhelming.  Overall, I'm really glad I stayed here and not one of the gravel lots in valdez.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56b646ed2220b77f:0xd8975e316de80952'},
#  {'user_id': '108989634908602011119',
#   'name': 'Daniel Formoso',
#   'time': 1529649811341,
#   'rating': 5,
#   'text': "Probably the nicest and cleanest campground we've been to in Alaska.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56b646ed2220b77f:0xd8975e316de80952'},
#  {'user_id': '115738865548796071801',
#   'name': 'Victoria Cook',
#   'time': 1466170294782,
#   'rating': 5,
#   'text': 'Great, slept like a bear. Clean, convenient, cute, the owners are a hoot.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56b646ed2220b77f:0xd8975e316de80952'},
#  {'user_id': '116393231987956549910',
#   'name': 'Matt H',
#   'time': 1625369270215,
#   'rating': 5,
#   'text': "It is always a treat to visit this rain or shine. So much to say but I'll sum it up with photos.",
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipPkduxfIBKbOE_g_TiH4M3jddBewzyyoq4xx9OX=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPRJqF410GEY71osSqIp_g8eZChLWZTkqhFnckH=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPzBt3cLSAXiQn_pqsOjtzgZOlPMUwjhzfBMf8e=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPP9USBVJYb4qc5-24m0FMVsZYM3wDtquca7l-5=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipNIOtDemIN_S4N688TreUWegsJhQmowx9BzbL7V=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipO3qqFNfi88pqCzWNKMgfCtzH1LX4j7EVQvsgsm=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x56c8992b5dee7225:0x9f7f4bf151868cf7'},
#  {'user_id': '117985992059356012741',
#   'name': 'Claudie',
#   'time': 1629350418882,
#   'rating': 4,
#   'text': "Only 3 booths with mainly vegetables. More expensive than the stores but the produce looked pretty good. The tomatoes were a nice deep red. Tomorrow I'll see if they taste better. I'm trying to eat healthier. I miss the fruits tho'.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8992b5dee7225:0x9f7f4bf151868cf7'},
#  {'user_id': '115658246644483827476',
#   'name': 'Crystal Dahle',
#   'time': 1630382185833,
#   'rating': 2,
#   'text': 'Not a lot going on here since it moved from downtown. Check out a farmers market somewhere else. Try find where Grandma Wei moved to!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8992b5dee7225:0x9f7f4bf151868cf7'},
#  {'user_id': '103655755742322578001',
#   'name': 'John Deal',
#   'time': 1631131711388,
#   'rating': 3,
#   'text': "It's a market",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8992b5dee7225:0x9f7f4bf151868cf7'},
#  {'user_id': '116978519893930605788',
#   'name': 'Holly Anne',
#   'time': 1629595392534,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8992b5dee7225:0x9f7f4bf151868cf7'},
#  {'user_id': '109748980961787042558',
#   'name': 'Emma Forsberg',
#   'time': 1629598102068,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8992b5dee7225:0x9f7f4bf151868cf7'},
#  {'user_id': '106927921983372472765',
#   'name': 'sherry miller',
#   'time': 1630540491895,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8992b5dee7225:0x9f7f4bf151868cf7'},
#  {'user_id': '117655458045608856003',
#   'name': 'Amy Lieb',
#   'time': 1630292802235,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8992b5dee7225:0x9f7f4bf151868cf7'},
#  {'user_id': '118331091891839753263',
#   'name': 'Phillip Lekanof',
#   'time': 1624600737849,
#   'rating': 5,
#   'text': "Great help, and didn't cost an arm and a leg. I was impress by the turn around time, and the fact that he was able to service my trailer so quickly. Other shops in my area were telling me that an appointment were a month out, I got serviced in two days. It was worth the trip from Anchorage. Give Max a call!",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '108676492248120451765',
#   'name': 'Cre•dence 52',
#   'time': 1630669457601,
#   'rating': 5,
#   'text': 'Matt was honest and did the work done as promised date.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '116945588442009928327',
#   'name': "The East's",
#   'time': 1617897565122,
#   'rating': 5,
#   'text': 'Max at Happy Camper is the best. Happy Camper installed a generator for my 5th wheel, great work. I was so pleased that I have taken my rig back for a slide out repair. No worries here.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '117354022227114826546',
#   'name': 'Julie Str',
#   'time': 1601734456932,
#   'rating': 5,
#   'text': "Extremely easy to work with. Highly accommodating.  Never once had an issue reaching him by phone. Was a little concerned at first with the couple of negative reviews but decided to try it anyway. So glad I did because I haven't received this high quality of customer service in a long time. I thought I needed a new water heater that he could have easily charged me for, turns out I didn't need one. Thats the kind of service a female like myself appreciates when dealing with repair shops. I won't take my trailer anywhere else for repairs but here.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '110352467269495760166',
#   'name': 'Jennifer Seutter',
#   'time': 1559572834719,
#   'rating': 5,
#   'text': 'Always great service, honest and fast.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '104226162488021398055',
#   'name': 'Don Jacobs',
#   'time': 1538892023742,
#   'rating': 5,
#   'text': 'Probably the best service in the Valley.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '114186812886403344337',
#   'name': 'Bri Pete',
#   'time': 1506407158815,
#   'rating': 1,
#   'text': 'Fixed camper',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '106927425466442385967',
#   'name': 'Saralan Ruth Hancock',
#   'time': 1590877018198,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '102143090164375827775',
#   'name': 'AK Woman',
#   'time': 1513575394394,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e0455225be87:0xf24828df75e2f8ae'},
#  {'user_id': '110036829333407795103',
#   'name': 'MR. Brandon RILEY',
#   'time': 1523541421847,
#   'rating': 5,
#   'text': 'It is the most beautiful awesome clean smelling air that I have ever came back to from down south and you will never find another place like it',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c2519bcfa6ccd:0xb5e1489a820445f8'},
#  {'user_id': '105737959930315802253',
#   'name': 'Fred Rosa',
#   'time': 1565320690274,
#   'rating': 3,
#   'text': "Didn't see it",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c2519bcfa6ccd:0xb5e1489a820445f8'},
#  {'user_id': '117085642984818409937',
#   'name': 'John Herman',
#   'time': 1567992031983,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c2519bcfa6ccd:0xb5e1489a820445f8'},
#  {'user_id': '114296104942073450163',
#   'name': 'Brianne Belford',
#   'time': 1565031512310,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c2519bcfa6ccd:0xb5e1489a820445f8'},
#  {'user_id': '115318910160813038880',
#   'name': 'Amelia Hendrickson',
#   'time': 1565628571929,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c2519bcfa6ccd:0xb5e1489a820445f8'},
#  {'user_id': '108958904934316809199',
#   'name': 'David A. Sanders Sr',
#   'time': 1627543465008,
#   'rating': 1,
#   'text': 'Didn\'t rent a room here because of the "run-around." Could barely get ahold of the owner. And, when I did, he was in Texas! I still couldn\'t rent a room because, there wasn\'t anyone else that could do the paperwork. If you rent from here, make sure the owner is available, and has the staff needed to handle your concerns.',
#   'pics': None,
#   'resp': {'time': 1627619621792,
#    'text': 'That is correct I was in Texas because my father had a stroke. We are always here to help our customers on top of it we did not have any vacancies at the time either we are generally full and have a very very small windows of availability. I certainly hope your father is in good health and not going through what mine is going through.'},
#   'gmap_id': '0x56c89632d94b816d:0x36d53dd6adaede05'},
#  {'user_id': '118236873308208229241',
#   'name': 'J T',
#   'time': 1519859896274,
#   'rating': 4,
#   'text': "Was a really good experience, the hotel management was pleasant and very helpful. Bathroom and kitchen area was clean and not in disrepair. The only thing I could say I didn't like was the big huge windows that let everyone see into the place, but that's not the worst thing to have. Definitely give this place a try if it's what you're looking for.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89632d94b816d:0x36d53dd6adaede05'},
#  {'user_id': '112200908444782890910',
#   'name': 'Chris Tadda',
#   'time': 1574034746154,
#   'rating': 5,
#   'text': 'Nice Room. Get to Know Other Guest. Makes aBetter Stay Being Considerate and Friendly!',
#   'pics': None,
#   'resp': {'time': 1627619744389, 'text': 'Thank you!'},
#   'gmap_id': '0x56c89632d94b816d:0x36d53dd6adaede05'},
#  {'user_id': '117591241048869840570',
#   'name': 'Alexi Shaw',
#   'time': 1549097571047,
#   'rating': 2,
#   'text': 'Super ghetto',
#   'pics': None,
#   'resp': {'time': 1627619809709,
#    'text': 'I wish the other Aurora limo in will change their name because yes they are super ghetto and we are not'},
#   'gmap_id': '0x56c89632d94b816d:0x36d53dd6adaede05'},
#  {'user_id': '116596160020338706626',
#   'name': 'Klaryssa lynn',
#   'time': 1519350178408,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89632d94b816d:0x36d53dd6adaede05'},
#  {'user_id': '110032316732745854021',
#   'name': 'Roger Gaston',
#   'time': 1529372046727,
#   'rating': 3,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89632d94b816d:0x36d53dd6adaede05'},
#  {'user_id': '116373627904798482387',
#   'name': 'Kim Shoecraft',
#   'time': 1568230454943,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': {'time': 1627619777458, 'text': 'Thank you'},
#   'gmap_id': '0x56c89632d94b816d:0x36d53dd6adaede05'},
#  {'user_id': '107172504421523845944',
#   'name': 'Rice Marley',
#   'time': 1530512925666,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89632d94b816d:0x36d53dd6adaede05'},
#  {'user_id': '107020138351278043466',
#   'name': 'Red Hood inc.',
#   'time': 1624323783962,
#   'rating': 5,
#   'text': 'Compared to the other taxi companies in Anchorage these guys were great. The communication I got was outstanding.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '100759990803009170676',
#   'name': 'twig nation',
#   'time': 1626399614413,
#   'rating': 1,
#   'text': 'Because my review was submitted at a certain time does not mean it was the time of my experience which happened 2 days before I posted my reveiw',
#   'pics': None,
#   'resp': {'time': 1626271044881,
#    'text': 'What was your experience? Your review was submitted at 4am we do not open until 6am and close at 12 midnite. Sorry if you called during the hours we are closed have a good day and try us when we are open. Thank you'},
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '106479243087079694734',
#   'name': 'S L Kerr',
#   'time': 1595662848547,
#   'rating': 5,
#   'text': 'First class service.  A delight to find in a taxi service.',
#   'pics': None,
#   'resp': {'time': 1596299646255, 'text': 'Thank you!!!'},
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '106544555899700737744',
#   'name': 'Jeff Allmendinger',
#   'time': 1583550183524,
#   'rating': 1,
#   'text': "WOW... Did this company really just release someone's personal number...? That seems very unprofessional. Let me get this straight. You got a bad review, and lashed out with someone's personal info? Say there, what's your number? I'd like to share it with.... NO ONE! Because that doesn't seem right.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '111571273138697343206',
#   'name': 'Julia Davenport',
#   'time': 1604540018421,
#   'rating': 1,
#   'text': 'Numbers down not sure of this company is still in buisness.',
#   'pics': None,
#   'resp': {'time': 1604702798718,
#    'text': "The phone is working, however we do not offer service between 12am to 8am currently because of the pandemic. We do prebooks 24hrs a day with advance notice. Some customers have been put on a no cab list for bad behavior. Let's hope your not on the the no cab list. Have a great and safe day. City Taxi staff"},
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '100108220591188643236',
#   'name': 'Brian',
#   'time': 1595986908591,
#   'rating': 1,
#   'text': 'Said they won’t come to old Seward and 70th don’t have service in that area',
#   'pics': None,
#   'resp': {'time': 1596299616235,
#    'text': 'We only had one taxi out because of the pandemic. We can not get to every call that comes in to dispatch. We could not get to your requested area at that time sir..We suggested that you call another service as we could not respond at that time. Sorry for the inconvenience have a good weekend.'},
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '111310038971558890385',
#   'name': 'crypto currency',
#   'time': 1601512788039,
#   'rating': 1,
#   'text': "Couldn't get through to dispatch and did not use due to this.",
#   'pics': None,
#   'resp': {'time': 1601523571009,
#    'text': 'We are a small taxi company we cant always answer every call. We also have reduced hours because of the current pandemic. Other options Yellow cab, Independent Taxi, People Mover, and Uber & Lyft. Thank you very much for your review'},
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '109490501023107359057',
#   'name': 'B. F.M',
#   'time': 1547619796323,
#   'rating': 5,
#   'text': 'Very quick to respond with a taxi after requesting one. Seems like a good alternative to yellow and checker cabs.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '113306450984083783396',
#   'name': 'Jennifer Mack',
#   'time': 1553972962368,
#   'rating': 1,
#   'text': 'Very rude people. I had to call back and ask for a taxi that would fit 4 adult and a kid, the man who answered rudely said you know what we can’t keep sending taxis out to you just call someone else. No one even came out and showed up. So how would it hurt to send someone with a bigger car. Very disrespectful. Don’t take this cab company just can yellow cab their much nicer. If I could rate this zero stars I would',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '113189885411577578727',
#   'name': 'Crys Tal',
#   'time': 1546837960780,
#   'rating': 1,
#   'text': 'Worst service ever. Save your time, use Ubee or Lfty.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '100429123515608579785',
#   'name': 'Josh Souvannakasy',
#   'time': 1617748871062,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '102109497481369569752',
#   'name': 'Steve Dahl',
#   'time': 1551038426358,
#   'rating': 1,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c89940e51d7375:0xeb800d5fe82cbd11'},
#  {'user_id': '109777236066234203597',
#   'name': 'Remy Partlow',
#   'time': 1495050813959,
#   'rating': 5,
#   'text': 'Quality local radio. Lots of awesome live performaces from Alaskan artists here. A nice place where nice people are.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '112450534644827085416',
#   'name': 'Patrick Race',
#   'time': 1470263495465,
#   'rating': 5,
#   'text': "The KTOO building houses KTOO, KXLL and KRNN, our local public radio stations. The building has several recording studios as well as a public studio space which can be used for public broadcasts or events.\n\nKTOO is also home to 360 North, a television station focused on public and regional affairs. Gavel Alaska is a service of KTOO that brings coverage of the geographically isolated state legislature to remote parts of the state.\n\nEveryone in the building is super friendly and helpful, like they're all characters from some 1970's episode of Sesame Street.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '109710823304129233243',
#   'name': 'rdj99833',
#   'time': 1548486211423,
#   'rating': 5,
#   'text': 'Great staff as well as divergent programming! Love to listen to the station!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '108956132254752217411',
#   'name': 'Ian Grant',
#   'time': 1481231226444,
#   'rating': 5,
#   'text': 'Attended a Chamber event here in the studio, the location, staff and all settings were top notch.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '116297133805270138306',
#   'name': 'David Jackson',
#   'time': 1527619455842,
#   'rating': 5,
#   'text': 'Flagship public media center for Southeast Alaska',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '101650331441285878014',
#   'name': 'Heather Warden',
#   'time': 1599941806612,
#   'rating': 5,
#   'text': 'Radio 🥀',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '100612490348267913741',
#   'name': 'Barb Kreher',
#   'time': 1563033984076,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '117056883296790018081',
#   'name': 'Bret Burnett',
#   'time': 1591441634895,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '117410094965643670586',
#   'name': 'Chan Valentine',
#   'time': 1496951952943,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '102612299984261447646',
#   'name': 'Nic Villasenor',
#   'time': 1536083652116,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '109937753533874234013',
#   'name': 'Todd Hunt',
#   'time': 1499714064604,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '111233459412839178925',
#   'name': 'Clint Carlson',
#   'time': 1531347242407,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '110850296356097865285',
#   'name': 'G Lee',
#   'time': 1560491794177,
#   'rating': 3,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '109410480180224323491',
#   'name': 'Matthew Austin',
#   'time': 1499383264925,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df83fb9c9d4b:0x21e0a32758d7b33c'},
#  {'user_id': '103767327638389213109',
#   'name': 'Justin C. Powell',
#   'time': 1616727094795,
#   'rating': 5,
#   'text': 'The kids pool is Sooooo warm.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df82e4ca2741:0x5c72dfc793b3cdfc'},
#  {'user_id': '115042298830844998595',
#   'name': 'Joshua Walton',
#   'time': 1611163497798,
#   'rating': 5,
#   'text': 'Old school, but my favorite pool in Juneau for what I do (mostly laps).',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df82e4ca2741:0x5c72dfc793b3cdfc'},
#  {'user_id': '109777236066234203597',
#   'name': 'Remy Partlow',
#   'time': 1495045582675,
#   'rating': 5,
#   'text': "I love this pool. It's an old facility and doesn't have a lot of fancy stuff, but it does its job being a center of community very well.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df82e4ca2741:0x5c72dfc793b3cdfc'},
#  {'user_id': '108956132254752217411',
#   'name': 'Ian Grant',
#   'time': 1478038945789,
#   'rating': 5,
#   'text': 'Favorite spot downtown for the kids',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df82e4ca2741:0x5c72dfc793b3cdfc'},
#  {'user_id': '108132985484403700427',
#   'name': 'Nathan Rogers',
#   'time': 1549377638264,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df82e4ca2741:0x5c72dfc793b3cdfc'},
#  {'user_id': '109877772311899726268',
#   'name': 'Max Cormier',
#   'time': 1607575395299,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df82e4ca2741:0x5c72dfc793b3cdfc'},
#  {'user_id': '103157427071160965296',
#   'name': 'Leila Marie',
#   'time': 1483609617482,
#   'rating': 2,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df82e4ca2741:0x5c72dfc793b3cdfc'},
#  {'user_id': '115664349673182595677',
#   'name': 'Scott Jones',
#   'time': 1608689957536,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df82e4ca2741:0x5c72dfc793b3cdfc'},
#  {'user_id': '117241290097326417173',
#   'name': 'Jeremy Bauer',
#   'time': 1579198565251,
#   'rating': 5,
#   'text': "It's one of my favorite shops in Juneau.  There is so much to discover and you couldn't find nicer people to help you.  It's locally owned and a huge supporter of Juneau!  It's a true gem in Downtown Juneau!",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df8320a87e6b:0x828a01cf6015dbf1'},
#  {'user_id': '114327589204819650406',
#   'name': 'Gabriel Cabasug',
#   'time': 1534449782306,
#   'rating': 5,
#   'text': 'One of my favorite stores in all of Alaska. Every visit to Juneau calls for a visit however brief it may be to Kindred Post. They have the very best greeting cards and post cards. Plus they make it so easy to mail just about anything. The staff here are always so welcoming and warm. The very best of Juneau!!',
#   'pics': None,
#   'resp': {'time': 1534915105881,
#    'text': "Thank you Gabriel! We're so glad we're a part of your Juneau routine! We appreciate you taking the time to compliment our collection and our team. We truly care about our customers and we're glad you felt it. May everyone you write to write back."},
#   'gmap_id': '0x5400df8320a87e6b:0x828a01cf6015dbf1'},
#  {'user_id': '117790520026358368567',
#   'name': 'John Heylin',
#   'time': 1452835697655,
#   'rating': 5,
#   'text': "Awesome! A post office? Sure. But the quality of goods they have for sale here is like nothing I've seen anywhere else. Looking for a gift to give to family back home?  This place is great. A slice of individuality in an area with lots of the same stuff for sale.",
#   'pics': None,
#   'resp': {'time': 1534915545019,
#    'text': 'Thank you! We strive to keep things fresh while honoring the traditions of our people, place, and past. Thank you for noticing!'},
#   'gmap_id': '0x5400df8320a87e6b:0x828a01cf6015dbf1'},
#  {'user_id': '115952534696397849681',
#   'name': 'Dr. Martha Martinez',
#   'time': 1500452850922,
#   'rating': 5,
#   'text': 'Best post office ever!  Great location; quick, friendly service; delightful art, unique gifts and souvenirs.  Popular with locals and tourists alike.',
#   'pics': None,
#   'resp': {'time': 1534915286742,
#    'text': 'Thank you Dr. Martinez! Thank you for enjoying our post office, our people, and our art. And thank you for taking the time to write this kind review.'},
#   'gmap_id': '0x5400df8320a87e6b:0x828a01cf6015dbf1'},
#  {'user_id': '109031737657668817657',
#   'name': 'Sara Caldwell',
#   'time': 1494004932702,
#   'rating': 4,
#   'text': 'Lovely post office, little wait and unusual and lovely gifts.',
#   'pics': None,
#   'resp': {'time': 1534915407810,
#    'text': 'I love this review. I too strive to have little wait, and unusual and lovely gifts, to be honest. Thank you, Sara for taking the time to visit and taking the time to write.'},
#   'gmap_id': '0x5400df8320a87e6b:0x828a01cf6015dbf1'},
#  {'user_id': '108956132254752217411',
#   'name': 'Ian Grant',
#   'time': 1478066882157,
#   'rating': 5,
#   'text': 'A little of everything wonderful 😉',
#   'pics': None,
#   'resp': {'time': 1534915441627,
#    'text': "Thank you, Ian! Couldn't of done it without you."},
#   'gmap_id': '0x5400df8320a87e6b:0x828a01cf6015dbf1'},
#  {'user_id': '116820482396911267609',
#   'name': 'Will Muldoon',
#   'time': 1506191897136,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x5400df8320a87e6b:0x828a01cf6015dbf1'},
#  {'user_id': '115754376075691949610',
#   'name': 'Gary Patterson',
#   'time': 1561441180715,
#   'rating': 5,
#   'text': 'Georgeous',
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipO-pVf0kwNA0wmcO-CSsPoytma8N_aFNzo6956v=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipMbzSb5NSbYiDxaOy2lTb20Ry6o7Kr3KRGe3_nU=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPxkoycPqwXjnVMwVZZWVN1CRUWqLHh2AwBo04y=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipMu0b3AyG7782mH7o9ZPFfTLT03mxDYms2Fx8Kr=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPglTCngEtH0uEolsQjQdEDWb8lKpSCukh6FhZI=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipOG_RxBjnMaCwCK2M3ARI_AsZhG-t5LBkWZ8Wc4=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipOTOi0j5V2KOODVtbVNg4z5qr_6YCodiV8AVv6l=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPOCbQwtFVzNF_2V3NTTazuCUOxHP_B4nipnBMR=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPe0MSqdwUsFwLxGHAhzGNGpKTJbUQOa-PcJepR=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPzViOj6lcVYT4JP4YbXlLzQizMuujNobfStZrP=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipP7JKvhAryPRNQlVnnETFDqOy4N0dipJEdgOqWo=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPaN_UeLXCnt2IZeWL0BPu3LWH2mplD8EAHCrls=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPddvXuY3VxsO9xIA15s1NAN_Z_iL_fYRSe47R1=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1Q
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x54011df245855521:0x5b18e929db82c6c0'},
#  {'user_id': '104636087243413913502',
#   'name': 'James Brooks',
#   'time': 1587167966363,
#   'rating': 5,
#   'text': "Fishermen's Bend is a card-lock gas station with no on-site staff. It has the lowest gasoline prices in Juneau. The station used to have a store as well, but that burned down in 2008.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x54011df245855521:0x5b18e929db82c6c0'},
#  {'user_id': '108956132254752217411',
#   'name': 'Ian Grant',
#   'time': 1478101288525,
#   'rating': 5,
#   'text': 'Often better prices than around town, straight gas and nothing else here',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x54011df245855521:0x5b18e929db82c6c0'},
#  {'user_id': '117307434639872199087',
#   'name': 'Kari Hull',
#   'time': 1567382986111,
#   'rating': 5,
#   'text': 'Quick in and out!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x54011df245855521:0x5b18e929db82c6c0'},
#  {'user_id': '107675627656859547749',
#   'name': 'Richard Zordani Sr',
#   'time': 1564702627482,
#   'rating': 5,
#   'text': 'Nice place',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x54011df245855521:0x5b18e929db82c6c0'},
#  {'user_id': '108955771300070587124',
#   'name': 'Katie Engwall',
#   'time': 1549506902982,
#   'rating': 5,
#   'text': 'I love this cafe! The staff are super friendly, the food is absolutely amazing, and the coffee is delicious! Great little cafe with a wonderful, welcoming atmosphere!',
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipPfKWckGS4dV4hhuT6MRKdI1SvnfrrlxuBwxu4i=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x56c12d17cbe70001:0x525edee85a348998'},
#  {'user_id': '107486890939058752728',
#   'name': 'Nathan Simpson',
#   'time': 1534903751311,
#   'rating': 5,
#   'text': "Anyone who takes any trips out on East End Road is bound to end up here. They love their plants and their regulars. It's fun to try out barista specials and trust them to treat you to the best of their abilities.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d17cbe70001:0x525edee85a348998'},
#  {'user_id': '103917147795908336085',
#   'name': 'nclgmb',
#   'time': 1567124354079,
#   'rating': 5,
#   'text': 'Breve to die for! Their breakfast sandwich is delicious. And the quality beverage doesnt waiver from barista to barista. Excellent every visit',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d17cbe70001:0x525edee85a348998'},
#  {'user_id': '113510759536703552905',
#   'name': 'zac AkFarNorth',
#   'time': 1508032581815,
#   'rating': 4,
#   'text': "Very good lol make a breakfast Sandi to put mcgriddle out and I'll be there every day",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d17cbe70001:0x525edee85a348998'},
#  {'user_id': '104269314264777029226',
#   'name': 'Melon Purcell',
#   'time': 1562020001809,
#   'rating': 5,
#   'text': 'Love the breakfast burrito..lots of great veggies!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d17cbe70001:0x525edee85a348998'},
#  {'user_id': '108170810760819743112',
#   'name': 'Dennis Rollins',
#   'time': 1540949329081,
#   'rating': 4,
#   'text': 'Well stocked and has pretty much everything you should need for any home project.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d17cbe70001:0x525edee85a348998'},
#  {'user_id': '102573442156874917844',
#   'name': 'Geoffrey Booth',
#   'time': 1622915705010,
#   'rating': 5,
#   'text': 'Almost had an ace from the alternate tee box',
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipPnBgtBK0FUcfZXEhGUYkN1MrmJDZM9F8MVizW_=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipNOCi6shm946YsZldMd0e21GPCC9p9u_mROB58t=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipN8m68xJ2CLfimtcPS1pnYpRmHNt158Af9_p4_r=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipO3xXXjM_qqlS57tDiPZonf2WXhrc89cIf2SuvR=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipP3VieNLL4png4xBwfODRCC3YJxUQ2_tfRoF8PB=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipP_tx4I_-_DhjaimjustE9sSo3eii6N1eMph6Wu=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '105709311350952304921',
#   'name': 'Brent Ensign',
#   'time': 1577300225926,
#   'rating': 5,
#   'text': 'Great place to empty a six pack with your friends while wandering around in the woods and throwing stuff.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '111854734654362092844',
#   'name': 'Maryah Showalter',
#   'time': 1562388668409,
#   'rating': 5,
#   'text': 'Well maintained and super fun just watch out for moose',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '108955771300070587124',
#   'name': 'Katie Engwall',
#   'time': 1557287745585,
#   'rating': 5,
#   'text': 'What a fun course for disc golf! We will be back often!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '109708631584952712541',
#   'name': 'Aaron Gray',
#   'time': 1562911181591,
#   'rating': 4,
#   'text': 'Group needs to collectively come together and cut down the brush',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '111502613595030643889',
#   'name': 'Tanya-Ann Lemieux',
#   'time': 1527705973687,
#   'rating': 5,
#   'text': 'I love this game!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '104935126931784766759',
#   'name': 'Susan Dunson',
#   'time': 1512318522500,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '111838710353450277141',
#   'name': 'Ineke Buchman',
#   'time': 1583017826871,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '115153643420593096919',
#   'name': 'Andrea Kimmel',
#   'time': 1562349437122,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d743090ab99:0xdb11d2fd7679516d'},
#  {'user_id': '101869976041207929724',
#   'name': 'Gus Cotten',
#   'time': 1513721178420,
#   'rating': 5,
#   'text': 'Helpful and friendly staff to cheer you up after you see how much gas your boat takes.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12c0ff2504ca5:0x452bf5b902b2e9c4'},
#  {'user_id': '112401657129222617469',
#   'name': 'Sima Basargin',
#   'time': 1590819427739,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12c0ff2504ca5:0x452bf5b902b2e9c4'},
#  {'user_id': '103917147795908336085',
#   'name': 'nclgmb',
#   'time': 1560041506069,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12c0ff2504ca5:0x452bf5b902b2e9c4'},
#  {'user_id': '108955771300070587124',
#   'name': 'Katie Engwall',
#   'time': 1561964923477,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12c0ff2504ca5:0x452bf5b902b2e9c4'},
#  {'user_id': '111915361138780942187',
#   'name': 'Igor Soulrabbit',
#   'time': 1566464484881,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12c0ff2504ca5:0x452bf5b902b2e9c4'},
#  {'user_id': '112408467552252080949',
#   'name': 'Star Schweitzer',
#   'time': 1535817478554,
#   'rating': 5,
#   'text': 'Amazing place to go... highly recommend',
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipMwfde76YL-9XXpTsNLOEOnOriDtXLb7-1Yknfr=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipNQszLPeH-gI5cDJMy8_XIRrdl0U7tlWex1YwBA=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec'},
#  {'user_id': '108932936840826135269',
#   'name': 'Justen Noffke',
#   'time': 1584600312818,
#   'rating': 5,
#   'text': 'Know the mechanics personally. Very hard working honest men. Will be taking all my vehicles here when they need service or repair.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec'},
#  {'user_id': '113565426728260009650',
#   'name': 'Craig Omalley',
#   'time': 1539586728847,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec'},
#  {'user_id': '112733053966586746240',
#   'name': 'Bob Bond',
#   'time': 1620435946548,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec'},
#  {'user_id': '111838710353450277141',
#   'name': 'Ineke Buchman',
#   'time': 1583017973730,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec'},
#  {'user_id': '100157067358898583495',
#   'name': 'Sabrina Schweitzer',
#   'time': 1561906449454,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec'},
#  {'user_id': '116988076772120004041',
#   'name': 'p o',
#   'time': 1539729927769,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c12d16a9cc3d2d:0xe056fbd6d7eae3ec'},
#  {'user_id': '108925024482067883352',
#   'name': 'Tina Mullins',
#   'time': 1622934352342,
#   'rating': 5,
#   'text': 'The creek runs along residences',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3'},
#  {'user_id': '113928054885307774676',
#   'name': 'Ed Rock',
#   'time': 1550747718757,
#   'rating': 5,
#   'text': 'The creek has a small salmon run in August.You can drive the old on Glen Highway leaving Palmer across the Matanuska Bridge and there are pull-offs to Park and cross the highway carefully. There are salmon in the creek but a lot less than I used to be.. There is a nice bike trail along the way next to the highway on the right. There are eagles and nests if you know where to look, alongside the turnouts where you look for the salmon. No fishing and watch for cars crossing the road. But lots of beautiful photo opportunities.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3'},
#  {'user_id': '104594578277846795859',
#   'name': 'Sachiko Brandl',
#   'time': 1567207123442,
#   'rating': 5,
#   'text': 'Love this little creek. Tranquil and perfect.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3'},
#  {'user_id': '118312768102672824257',
#   'name': 'Chesty Puller',
#   'time': 1522717130539,
#   'rating': 3,
#   'text': 'Its a creek',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3'},
#  {'user_id': '113594226284187074908',
#   'name': 'Marjorie Trull',
#   'time': 1568899392385,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3'},
#  {'user_id': '103907803930819061577',
#   'name': 'Admiral Seabek',
#   'time': 1558938252918,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c8e2b7e78a1ec9:0x79383d16d0fad8a3'},
#  {'user_id': '105007179558367506362',
#   'name': 'Cherokee Jasper Travis Babo Dorsey',
#   'time': 1541477425002,
#   'rating': 5,
#   'text': 'Loved getting seen today they did a amazing job with me and my two kids and my wife!! Fast friendly!! My wife needed to wait while I got some work done they let our two year old play with toys and color!! I recommend them!!!! Well just went back today they did amazing job on my son!\n\n11-5-18\nSeen today by Dr.Hyung, Jan and Kap!\nThey have been amazing with all four kids! The three of them have helped/worked on all four kids today! Ages two through nine years old! We will be coming back again for more check ups as needed! They were very good with my two year and four year old the whole time! Thank you guys keep up the good work!',
#   'pics': None,
#   'resp': {'time': 1543551369057,
#    'text': 'Wow thank you so much for such a kind and generous review Travis! We are always striving to be better for our patients every day (bty: better than yesterday)! Thank you for reminding us why we do what we do everyday! Hope to see you soon, from the entire btyDENTAL family!'},
#   'gmap_id': '0x56c896656151ce19:0xd11d2ef0be67916a'},
#  {'user_id': '106533417341487542265',
#   'name': 'Jade Alaniz',
#   'time': 1547237024627,
#   'rating': 1,
#   'text': "So long story but they're scammers for people in the military! I went in to have an exam and fillings done and the total came out to 400$! I thought that was completely wrong!! So I called my insurance and turns out I was right! I should've only been paying 50$ for the all the fillings and when I called BTY to confront them all they said is they haven't received their money from my insurance and that I still needed to pay and would not get reimbursed I literally went the other day insurance takes a bit to take over...and they wanted their money up front with running it through my insurance, they also said I needed 2 crown and I got a second opinion because I'm only 19! And I've never had a problem with my teeth so I went to another dentist to look and he said nothing was wrong with my teeth and I probably didn't need the fillings to begin with and they did such a bad job on the fillings too to the point my gums and teeth hurt so bad I can't stop crying",
#   'pics': None,
#   'resp': {'time': 1547252782938,
#    'text': 'Thank you for your feedback; however, we are unable to locate you as a patient in our records. We would like to look into this matter further, so if you wouldn’t mind private messaging us your name that was used in our office, we will work on addressing this as quickly as we can.'},
#   'gmap_id': '0x56c896656151ce19:0xd11d2ef0be67916a'},
#  {'user_id': '113678805894412138653',
#   'name': 'Nichole Sandahl',
#   'time': 1532058332527,
#   'rating': 5,
#   'text': 'I have avoided going to dentists my adult life since everytime i went i had terrible experiences!!! This place has changed my views... Excellent doctor and staff. My 1st visit they explained the limits of my coverage...what they could do, what they reccommended and when my insurace rolled over i was back for more! Highly reccommend them. Friendly fast and great hours!',
#   'pics': None,
#   'resp': {'time': 1532738460939,
#    'text': 'Thank you for choosing btyDental Nichole! See you soon and thank you for the review!'},
#   'gmap_id': '0x56c896656151ce19:0xd11d2ef0be67916a'},
#  {'user_id': '101496959232520348740',
#   'name': 'Slim_ Bit_',
#   'time': 1468011165959,
#   'rating': 5,
#   'text': 'Dr. Cha is an amazing dentist and his assistant clairabelle was beyond an amazing person also i would definately recommend patients here all of the staff are very pleasant.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c896656151ce19:0xd11d2ef0be67916a'},
#  {'user_id': '108916058359946811969',
#   'name': 'bonecrusher 77',
#   'time': 1518731458572,
#   'rating': 5,
#   'text': 'Awesome Dr Man and assistance Willow, Cory fast and painless.',
# ...
#  {'user_id': '116369736418994061272',
#   'name': 'Adrianna Miller',
#   'time': 1510987215048,
#   'rating': 5,
#   'text': 'Great place, haven’t personally attended Church. Have been for Right to Life Banquets that were hosted there.',
#   'pics': None,
#   'resp': {'time': 1624295967693,
#    'text': 'We were blessed to host Right to Life Banquets in the past.  Thank you for your review!'},
#   'gmap_id': '0x56c91ef66e968da1:0xf1188333a3b8eed8'},
#  {'user_id': '105849569112199411802',
#   'name': 'Grace Leblanc',
#   'time': 1576195636899,
#   'rating': 4,
#   'text': 'Lovely church',
#   'pics': None,
#   'resp': {'time': 1623950575720,
#    'text': 'Thank you so much for the compliment!'},
#   'gmap_id': '0x56c91ef66e968da1:0xf1188333a3b8eed8'},
#  {'user_id': '108405673139638715603',
#   'name': 'Kym Coffey',
#   'time': 1548243015541,
#   'rating': 5,
#   'text': 'The sermon was uplifting',
#   'pics': None,
#   'resp': {'time': 1623950713447, 'text': 'Praise God!'},
#   'gmap_id': '0x56c91ef66e968da1:0xf1188333a3b8eed8'},
#  {'user_id': '113862184681475255383',
#   'name': 'Bob and Linda Bates',
#   'time': 1554087993118,
#   'rating': 5,
#   'text': 'God is present here!',
#   'pics': None,
#   'resp': {'time': 1623950659522,
#    'text': "It is such an honor to sense God's presence in worship and in the preaching.  God is definitely working here, praise God!"},
#   'gmap_id': '0x56c91ef66e968da1:0xf1188333a3b8eed8'},
#  {'user_id': '112204754100996796730',
#   'name': 'kate 2064',
#   'time': 1563667551779,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': {'time': 1623950612666, 'text': 'Thank you!'},
#   'gmap_id': '0x56c91ef66e968da1:0xf1188333a3b8eed8'},
#  {'user_id': '101077825329075531076',
#   'name': 'Christopher Cole',
#   'time': 1544209700952,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': {'time': 1623950729441,
#    'text': "Thanks Chris!  It's a blessing to have you and your family at the church."},
#   'gmap_id': '0x56c91ef66e968da1:0xf1188333a3b8eed8'},
#  {'user_id': '113972021594894464504',
#   'name': 'Robyn Middleton',
#   'time': 1590914545184,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': {'time': 1623950490473,
#    'text': 'Thank you so much for your review, we deeply appreciate it!'},
#   'gmap_id': '0x56c91ef66e968da1:0xf1188333a3b8eed8'},
#  {'user_id': '116590835331997902884',
#   'name': 'John Wilkie',
#   'time': 1421350819476,
#   'rating': 4,
#   'text': "Came in here for a drink, and what I found was a live band playing French Canadian folk music (I assume). It was a darker atmosphere in which everyone seemed really friendly and to know each other. They have a nice lark beer selection on tap and a good bottle selection too. I didn't get to try their food, but there was something called the Spenard Dip that looked awesome. I'll definitely come back and if the food is as good at the atmosphere, I'll be changing my rating to 5 stars.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '111130607486220004130',
#   'name': 'Chelsea Cassell',
#   'time': 1487889318242,
#   'rating': 4,
#   'text': "Somedays are awesome at Taproot, somedays not so much.  They bring in some excellent local (and foreign) talent.  I would always check the calendar.  The food is good and the beer selection is great.  Never loved what the open mic night brings out.  Also, I do not advise going here on the cold days as their heating system cannot compensate and you're left huddling near one of the space heaters.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '117114811164806335062',
#   'name': 'abe kline',
#   'time': 1484179719303,
#   'rating': 4,
#   'text': "It's a bit cold inside. Science club is pretty awesome. Lecture by a knowledgeable scientist plus informal pub quiz for a free drink. Food is decent dive food",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '112911464363826067676',
#   'name': 'Brandon Wood',
#   'time': 1487796690929,
#   'rating': 4,
#   'text': 'Great food and drinks in a relatively small, intimate atmosphere.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '101939679586503307605',
#   'name': 'Roger Porter',
#   'time': 1474958578960,
#   'rating': 5,
#   'text': 'Always friendly staff and excellent quality live music.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '108401773419255733208',
#   'name': 'Robin Bassett',
#   'time': 1486404499972,
#   'rating': 5,
#   'text': 'Good food and great music always happening',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '117395666470507188750',
#   'name': 'Nicholas Abell',
#   'time': 1472084878159,
#   'rating': 5,
#   'text': 'Triva was a blast and open mic was fun.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '108819312702321013297',
#   'name': 'J Peterson',
#   'time': 1493400601413,
#   'rating': 4,
#   'text': 'Good food . GREAT music.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '116145733033048253036',
#   'name': 'Jeremy Garcia',
#   'time': 1494740109061,
#   'rating': 5,
#   'text': 'Butt soup ??   drinks , chached out lawyers, you name it😎👍.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '105094470032329431653',
#   'name': 'Cary Strahan',
#   'time': 1492981891456,
#   'rating': 3,
#   'text': 'Only went once to see a particular artist. Food was ok',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '105862018158110079877',
#   'name': 'Brice Wilbanks',
#   'time': 1464557822934,
#   'rating': 4,
#   'text': 'Came here for a catered event/venue and the staff did a nice job with the food and drinks.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '116109000908396928854',
#   'name': 'Oscar Alvarez',
#   'time': 1487057157511,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '104141927951950244171',
#   'name': 'Liviu Verziu',
#   'time': 1489635848771,
#   'rating': 3,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '105190659144720313090',
#   'name': 'Jordan Couture',
#   'time': 1479360533088,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '105783748386320191881',
#   'name': 'Nick Byars',
#   'time': 1479594217699,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '112183790597508181526',
#   'name': 'Charles Nick',
#   'time': 1474772555549,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '106230783818805036604',
#   'name': 'habanerosteele',
#   'time': 1447510515885,
#   'rating': 1,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '113609873569984179559',
#   'name': 'Ben Nove',
#   'time': 1379638869825,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '117619149999443497625',
#   'name': 'Erik Williams',
#   'time': 1477512664616,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '110038411345733948631',
#   'name': 'Justin Priest',
#   'time': 1459307879184,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x56c897dd0e701991:0xa345baf2459f9bba'},
#  {'user_id': '108394916883901531692',
#   'name': 'Becky Noyes',
#   'time': 1615758962079,
#   'rating': 5,
#   'text': "An awesome way to travel in Southeast Alaska.  The crew is excellent and the views are pretty spectacular!  If you want to experience the magic of Prinve of Wales Island and need a way to get over, this is the way to do it.  Don't forget to have a milkshake on your ride! :)",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '100101568063319648715',
#   'name': 'Noah Lucia',
#   'time': 1627926993913,
#   'rating': 5,
#   'text': 'Helpful staff easy to navigate',
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipNfuA_cbargsPvM28Ws429YJn7bxG6TTrAjT6RD=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '106070529575992315972',
#   'name': 'EDawn Shanks',
#   'time': 1476050478647,
#   'rating': 5,
#   'text': 'Like how relaxing it is waiting inside while waiting to board ferry.',
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipO_TVvCI4w0NNuh5VWgR9BxnAvJldppsn7y8aY3=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '113967954623342023424',
#   'name': 'rebecca M',
#   'time': 1476912222292,
#   'rating': 5,
#   'text': 'You guys are amazing.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '100455726082790311913',
#   'name': 'Brian Altringer',
#   'time': 1540601365391,
#   'rating': 4,
#   'text': 'Nice ride',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '116652238000712233803',
#   'name': 'Tim Huber',
#   'time': 1567099948297,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '114054691465685385969',
#   'name': 'Edward Weston',
#   'time': 1427960109514,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '101288454812889764250',
#   'name': 'Jack Random',
#   'time': 1617409158707,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '108062487350067074384',
#   'name': 'Tylo Kennedy',
#   'time': 1534436310267,
#   'rating': 4,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '101909880477289122675',
#   'name': 'Amy Duncan',
#   'time': 1627842850513,
#   'rating': 5,
#   'text': None,
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x540c25b8da39fa0d:0x325d0caccd5425b4'},
#  {'user_id': '110142789854474680448',
#   'name': 'AlaskA Trucker',
#   'time': 1613526311782,
#   'rating': 5,
#   'text': 'Great towing company! Would definitely use them again.',
#   'pics': None,
#   'resp': {'time': 1614872517815,
#    'text': 'Thank you so much for your outstanding review! It was my pleasure assisting you. Have a great day Alaska Trucker.'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '100307867908343918804',
#   'name': 'will young',
#   'time': 1611096018010,
#   'rating': 5,
#   'text': 'Great company to work with. Daut was on time and handled my car with care and professionalism. Hands down best tow company in AK as well as very resonable pricing. Will defently use for future tows.',
#   'pics': None,
#   'resp': {'time': 1611877870414,
#    'text': 'Thank you so much for your outstanding review! It was my pleasure assisting you. Have a great day Will.'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '108899547923815727151',
#   'name': 'MadTurboFreak Passion For Speed',
#   'time': 1615666892706,
#   'rating': 5,
#   'text': 'He is my hero 🙌 the only tow guy I have ever used that cares and can actually tow modified vehicles without damaging them, also one night I had a bad driver run me off into the snow bank and with the city snowplows only maybe a mile away I was stressed for time, called him at almost midnight and he was there and saved the day before the snowplows got me, only person I be calling for myself or my business 👍',
#   'pics': None,
#   'resp': {'time': 1616009508162,
#    'text': 'Thank you so much for your outstanding review! It was my pleasure assisting you. Have a great day Turbo Freak! 🚗💨'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '103438924951577986898',
#   'name': 'Joseph Lomman',
#   'time': 1596329902628,
#   'rating': 5,
#   'text': "Had my lowered 370Z towed from my home to a shop. Arrived earlier than expected and was able to get my car on the truck without scraping anything at all, and my car sits a half inch off the ground. If they can get my car on the bed, they can get anything on there. Didnt use the control arms to winch my car up which is a huge problem up here in Alaska! I've seen so many bent control arms due to other companes winching or strapping down from them. Honestly can't beat the service and the price for a tow. In town or not. Not the first time I've called Eagle towing, and definitely not the last! (Well hopefully I dont have to call again! 😁) thanks again for the great service!",
#   'pics': None,
#   'resp': {'time': 1596428795908,
#    'text': 'Thank you so much for your outstanding review! It was my pleasure assisting you. Have a great day.'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '106266128902962734190',
#   'name': 'Zenna W. “Zenna” N.',
#   'time': 1597386410999,
#   'rating': 5,
#   'text': 'They showed up when they said they would, hooked up my car no problem,and got it where it needed to go. Rates were very reasonable.',
#   'pics': None,
#   'resp': {'time': 1597387489383,
#    'text': 'Thank you so much for your outstanding review! It was my pleasure assisting you. Have a great day Wendy.'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '109548497602886050821',
#   'name': 'Jason Carter',
#   'time': 1579239741218,
#   'rating': 5,
#   'text': 'Excellent services provided, quick and efficient! Excellent prices, takes care of the customer and follows up after everything has been taken care of. Daut is a real go getter!! Thanks man.',
#   'pics': None,
#   'resp': {'time': 1579240253961,
#    'text': 'It was my pleasure towing your vehicle  thanks for the feedback'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '103809633823030875723',
#   'name': 'Cody W',
#   'time': 1610426958581,
#   'rating': 4,
#   'text': 'Great service, fast, and polite employees.',
#   'pics': None,
#   'resp': {'time': 1610427642704,
#    'text': 'Thank you so much for your outstanding review! It was my pleasure assisting you. Have a great day Cody.'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '101189462175227592755',
#   'name': 'John Haley',
#   'time': 1605732087027,
#   'rating': 5,
#   'text': 'Fast\nFriendly\nProfessional\n5/5',
#   'pics': None,
#   'resp': {'time': 1605890166170,
#    'text': 'Thank you so much for your outstanding review! It was my pleasure assisting you. Have a great day John.'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '108367009780501742118',
#   'name': 'jordan cuddy',
#   'time': 1601786401538,
#   'rating': 5,
#   'text': 'Took a lil while but they delivered. Appreciated the help and advice from the driver regards to my vehicles problems.',
#   'pics': None,
#   'resp': {'time': 1601797763830,
#    'text': 'Thank you so much for your outstanding review! It was my pleasure assisting you. Have a great day Jordan.'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  {'user_id': '106443142966271691839',
#   'name': 'Tana Kennedy',
#   'time': 1522100783424,
#   'rating': 5,
#   'text': "Best customer service out of the 12 companies I called he was the BeST!! Came and towed me immediately because of the location and chances of it being impounded even when I had said since it was midnight I didn't mind waiting until morning. Amazing company!!!",
#   'pics': None,
#   'resp': {'time': 1522101381297, 'text': 'Thanks for the feedback.'},
#   'gmap_id': '0x56c8977735f00f4d:0x7c4c5e3b378bc81a'},
#  ...]

# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import linear_model
from sklearn import metrics
import math

# %%
df = pd.read_csv('review-Alaska_10.csv')

# %% [markdown]
# #### Word Cloud Visualization E.g.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

df5 = df[(df['rating'] == 5) & (df['text'].notna())]

text5 = " ".join(df5['text'])

# Generate and display the word cloud
wordcloud5 = WordCloud(background_color="white").generate(text5)
plt.imshow(wordcloud5)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

df1 = df[(df['rating'] == 1) & (df['text'].notna())]

text1 = " ".join(df1['text'])

wordcloud1 = WordCloud(background_color="white").generate(text1)
plt.imshow(wordcloud1)
plt.axis("off")
plt.show()

# %%
df = df[df['text'].notna()]

# %%
df = df.sample(frac=0.2)

# %%
x = df['text']
y = df['rating']
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size = 0.2, random_state = 2022)

vectorizer = CountVectorizer(ngram_range = (1, 2), min_df=10)

vectorizer.fit(x_train)
X_train = vectorizer.transform(x_train)
X_test = vectorizer.transform(x_test)

X_train.toarray()
X_test.toarray()
Y_train = np.array(y_train)
Y_test = np.array(y_test)

regr = linear_model.LinearRegression()
regr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = regr.predict(X_test)
ssr = np.sum(Y_pred - np.mean(Y_test)) ** 2
mse = metrics.mean_squared_error(Y_test, Y_pred)
rmse = math.sqrt(mse)
print('R^2 score: %.2f' % regr.score(X_test, Y_test))
print('RMSE: %.2f' % rmse)
# Out:
# R^2 score: -0.17
# RMSE: 1.18

# %%
df_features = pd.DataFrame(data = {'Coefficient':list(regr.coef_),'Feature_Name':vectorizer.get_feature_names_out()})
df_features['Coefficient_Magnitude'] = abs(df_features['Coefficient'])
df_features.sort_values(by='Coefficient_Magnitude', ascending=False).head(10)
# Out:
#        Coefficient        Feature_Name  Coefficient_Magnitude
# 11756    -4.838714  strongly recommend               4.838714
# 11755     4.706648            strongly               4.706648
# 5795      4.214177          handful of               4.214177
# 5794     -4.139902             handful               4.139902
# 15337     3.778357                yell               3.778357
# 13603    -3.658907             to yell               3.658907
# 6056      3.507666      helpful please               3.507666
# 7383      3.507666         like button               3.507666
# 14290    -3.058847            wal mart               3.058847
# 14289     2.969144                 wal               2.969144

# %% [markdown]
# ### Lasso

# %%
alpha_list = [0.0001, 0.001, 0.01, 0.1]
col_labels_lasso = ['Alpha', 'Training RMSE', 'Model Complexity - Coef Norm1', 'Model Complexity - Coef Sum', 'Test RMSE']

result_lasso_arr = []
for alpha in alpha_list:
    result_lasso_list=[]
    #build model:
    lasso = linear_model.Lasso(alpha)
    lasso.fit(X_train, Y_train)
    #applied to test data
    Y_pred_test = lasso.predict(X_test)
    mse_test = metrics.mean_squared_error(Y_test, Y_pred_test)
    rmse_test = math.sqrt(mse_test)
    #applied to train data
    Y_pred_train = lasso.predict(X_train)
    mse_train = metrics.mean_squared_error(Y_train, Y_pred_train)
    rmse_train = math.sqrt(mse_train)
    #compute complexity by L1-norm of the model parameter values
    complexity_coef_norm1 = np.linalg.norm(lasso.coef_, ord=1)
    #compute complexity by sum of the model parameter magnitudes
    complexity_coef_sum = np.sum(np.abs(lasso.coef_))
    #output result
    print(f'Alpha value: {alpha}')
    print(f'Train RMSE: {rmse_train}')
    print(f'Model Complexity - Norm1 of Coefficients: {complexity_coef_norm1}')
    print(f'Model Complexity - Sum of Coefficients: {complexity_coef_sum}')
    print(f'Test RMSE: {rmse_test}\n')
    result_lasso_list = [alpha, rmse_train, complexity_coef_norm1, complexity_coef_sum, rmse_test]
    result_lasso_arr.append(result_lasso_list)
    
df_lasso = pd.DataFrame(result_lasso_arr,columns=col_labels_lasso)
df_lasso
# Out:
# Alpha value: 0.0001
# Train RMSE: 0.7405364272236079
# Model Complexity - Norm1 of Coefficients: 469.11773280212594
# Model Complexity - Sum of Coefficients: 469.11773280212594
# Test RMSE: 0.8675390227275005
#
# Alpha value: 0.001
# Train RMSE: 0.8640549136016481
# Model Complexity - Norm1 of Coefficients: 37.75125538815346
# Model Complexity - Sum of Coefficients: 37.75125538815346
# Test RMSE: 0.8833538082742207
#
# Alpha value: 0.01
# Train RMSE: 0.9687215605920395
# Model Complexity - Norm1 of Coefficients: 4.0700465672016115
# Model Complexity - Sum of Coefficients: 4.0700465672016115
# Test RMSE: 0.9759447606483699
#
# Alpha value: 0.1
# Train RMSE: 1.065455181235364
# Model Complexity - Norm1 of Coefficients: 0.1357717240609411
# Model Complexity - Sum of Coefficients: 0.1357717240609411
# Test RMSE: 1.0774441437355682
#     Alpha  Training RMSE  Model Complexity - Coef Norm1  \
# 0  0.0001       0.740536                     469.117733
# 1  0.0010       0.864055                      37.751255
# 2  0.0100       0.968722                       4.070047
# 3  0.1000       1.065455                       0.135772
#
#    Model Complexity - Coef Sum  Test RMSE
# 0                   469.117733   0.867539
# 1                    37.751255   0.883354
# 2                     4.070047   0.975945
# 3                     0.135772   1.077444

# %%
lasso_best = linear_model.Lasso(0.0001)
lasso_best.fit(X_train, Y_train)
df_lasso_features = pd.DataFrame(data = {'Coefficient':list(lasso_best.coef_),'Feature_Name':vectorizer.get_feature_names_out()})
df_lasso_features['Coefficient_Magnitude'] = abs(df_lasso_features['Coefficient'])

# %%
df_lasso_features.sort_values(by='Coefficient_Magnitude', ascending=False).head(100)
# Out:
#        Coefficient      Feature_Name  Coefficient_Magnitude
# 13883    -1.462359               ugh               1.462359
# 11796    -1.461197             sucks               1.461197
# 5770     -1.039802           hair in               1.039802
# 5089     -1.034639           garbage               1.034639
# 15248    -1.028848             worst               1.028848
# ...            ...               ...                    ...
# 8623      0.499285  not disappointed               0.499285
# 9345     -0.496913          outdated               0.496913
# 432      -0.493642        always out               0.493642
# 3130     -0.493172        could give               0.493172
# 6815     -0.491330          isn very               0.491330
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Ridge

# %%
alpha_list = [0.0001, 0.001, 0.01, 0.1]
col_labels_ridge = ['Alpha', 'Training RMSE', 'Model Complexity - Coef Norm2', 'Model Complexity - Coef Sum', 'Test RMSE']

result_ridge_arr = []
for alpha in alpha_list:
    result_ridge_list=[]
    #build model:
    ridge = linear_model.Ridge(alpha)
    ridge.fit(X_train, Y_train)
    #applied to test data
    Y_pred_test = ridge.predict(X_test)
    mse_test = metrics.mean_squared_error(Y_test, Y_pred_test)
    rmse_test = math.sqrt(mse_test)
    #applied to train data
    Y_pred_train = ridge.predict(X_train)
    mse_train = metrics.mean_squared_error(Y_train, Y_pred_train)
    rmse_train = math.sqrt(mse_train)
    #compute complexity by L1-norm of the model parameter values
    complexity_coef_norm2 = np.linalg.norm(ridge.coef_, ord=2)
    #compute complexity by sum of the model parameter magnitude
    complexity_coef_sum = np.sum(np.abs(ridge.coef_))
    #output result
    print(f'Alpha value: {alpha}')
    print(f'Train RMSE: {rmse_train}')
    print(f'Model Complexity - Norm2 of Coefficients: {complexity_coef_norm2}')
    print(f'Model Complexity - Sum of Coefficients: {complexity_coef_sum}')
    print(f'Test RMSE: {rmse_test}\n')
    result_ridge_list = [alpha, rmse_train, complexity_coef_norm2, complexity_coef_sum, rmse_test]
    result_ridge_arr.append(result_ridge_list)

df_ridge = pd.DataFrame(result_ridge_arr,columns=col_labels_ridge)
df_ridge
# Out:
# Alpha value: 0.0001
# Train RMSE: 0.6135857201063474
# Model Complexity - Norm2 of Coefficients: 50.098464392934346
# Model Complexity - Sum of Coefficients: 4423.999669392935
# Test RMSE: 1.1833677894491126
#
# Alpha value: 0.001
# Train RMSE: 0.6135835576636322
# Model Complexity - Norm2 of Coefficients: 50.089549001696696
# Model Complexity - Sum of Coefficients: 4422.444841301154
# Test RMSE: 1.183216724782761
#
# Alpha value: 0.01
# Train RMSE: 0.6135912300535589
# Model Complexity - Norm2 of Coefficients: 49.58142179638357
# Model Complexity - Sum of Coefficients: 4395.835458082323
# Test RMSE: 1.18005139960543
#
# Alpha value: 0.1
# Train RMSE: 0.6138641953024995
# Model Complexity - Norm2 of Coefficients: 46.37826738020673
# Model Complexity - Sum of Coefficients: 4189.086244184224
# Test RMSE: 1.1559925035881264
#     Alpha  Training RMSE  Model Complexity - Coef Norm2  \
# 0  0.0001       0.613586                      50.098464
# 1  0.0010       0.613584                      50.089549
# 2  0.0100       0.613591                      49.581422
# 3  0.1000       0.613864                      46.378267
#
#    Model Complexity - Coef Sum  Test RMSE
# 0                  4423.999669   1.183368
# 1                  4422.444841   1.183217
# 2                  4395.835458   1.180051
# 3                  4189.086244   1.155993

# %%
ridge_best = linear_model.Ridge(0.1)
ridge_best.fit(X_train, Y_train)
df_ridge_features = pd.DataFrame(data = {'Coefficient':list(ridge_best.coef_),'Feature_Name':vectorizer.get_feature_names_out()})
df_ridge_features['Coefficient_Magnitude'] = abs(df_ridge_features['Coefficient'])
df_ridge_features.sort_values(by='Coefficient_Magnitude', ascending=False).head(10)

# %% [markdown]
# ### Regularized Logistic Regression

# %%
df_1_and_5 = df[(df.rating == 5) | (df.rating == 1)]

x = df_1_and_5['text']
y = df_1_and_5['rating']
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size = 0.2, random_state = 2022)

vectorizer = CountVectorizer(ngram_range = (1, 2), min_df=10)
X_train = vectorizer.fit_transform(x_train)
X_test = vectorizer.fit_transform(x_test)

vectorizer.fit(x)
X_train = vectorizer.transform(x_train)
X_test = vectorizer.transform(x_test)
Y_train = np.array(y_train)
Y_test = np.array(y_test)

# %% [markdown]
# #### L2

# %%
C_list = [0.001, 0.01, 0.1, 1, 10, 100] 
col_labels = ['C', 'Train AUC','Model Complexity - Coef Sum','Test AUC']

result_log_L2_arr = []
result_fpr_L2_arr = []
result_tpr_L2_arr = []
for c_value in C_list:
    result_log_L2_list = []
    
    # Build the logistic regression estimator with the specified C value
    estimator_L2 = linear_model.LogisticRegression(solver = 'liblinear', max_iter=1000, random_state=2022, C=c_value,penalty='l2') 
    estimator_L2.fit(X_train, Y_train)
    # Check the class order, make sure 5 is on the 2nd column
    print('Class order:',estimator_L2.classes_)
    if estimator_L2.classes_[1] == 5:
        print('Correct positive class selection')
    else:
        print('Incorrect positive class selection, check')
    
    # Calculate AUC_train by applying the estimator on X_train
    Y_train_pred_prob = estimator_L2.predict_proba(X_train)
    Y_train_pred_prob_5star = Y_train_pred_prob[:, 1]
    AUC_train = metrics.roc_auc_score(Y_train, Y_train_pred_prob_5star)
    
    # Calculate AUC_test by applying the estimator on X_test
    Y_test_pred_prob = estimator_L2.predict_proba(X_test)
    Y_test_pred_prob_5star = Y_test_pred_prob[:, 1]
    AUC_test = metrics.roc_auc_score(Y_test, Y_test_pred_prob_5star)
    
    # Calculate fpr and tpr from test data
    fpr, tpr, thresholds = metrics.roc_curve(Y_test, Y_test_pred_prob_5star, pos_label=5)
    
    # Compute complexity by sum of the model parameter magnitudes
    complexity_coef_sum = np.sum(np.abs(estimator_L2.coef_))
    
    # Compile results
    result_log_L2_list = [c_value, AUC_train, complexity_coef_sum, AUC_test]
    result_log_L2_arr.append(result_log_L2_list)
    result_fpr_L2_arr.append(list(fpr))
    result_tpr_L2_arr.append(list(tpr))
    
    print('C value:',c_value)
    print('Model Complexity:',complexity_coef_sum)
    print('Train_AUC:', AUC_train)
    print('Test_AUC:', AUC_test,'\n')

df_log_L2 = pd.DataFrame(result_log_L2_arr,columns=col_labels)
df_log_L2

# %%
colours=['r','g','b','k','m','c']
plt.figure(figsize = (8, 8))
for i in range(len(result_fpr_L2_arr)):
    plt.plot(result_fpr_L2_arr[i],result_tpr_L2_arr[i],colours[i])
plt.gca().legend(df_log_L2['Test AUC'])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.show()

# %%
estimator_L2_best = linear_model.LogisticRegression(solver = 'liblinear', max_iter=1000, random_state=2022, C=0.01,penalty='l2') 
estimator_L2_best.fit(X_train, Y_train)

df_L2_features = pd.DataFrame(data = {'Coefficient':estimator_L2_best.coef_.tolist()[0],'Feature_Name':vectorizer.get_feature_names_out()})
df_L2_features['Coefficient_Magnitude'] = abs(df_L2_features['Coefficient'])
df_L2_features.sort_values(by='Coefficient_Magnitude', ascending=False).head(10)

# %% [markdown]
# #### L1

# %%
C_list = [0.001, 0.01, 0.1, 1, 10, 100] 
col_labels = ['C', 'Train AUC','Model Complexity - Coef Sum','Test AUC']

result_log_L1_arr = []
result_fpr_L1_arr = []
result_tpr_L1_arr = []
for c_value in C_list:
    result_log_L1_list = []
    
    # Build the logistic regression estimator with the specified C value
    estimator_L1 = linear_model.LogisticRegression(solver = 'liblinear', max_iter=1000, random_state=2022, C=c_value,penalty='l1') 
    estimator_L1.fit(X_train, Y_train)
    # Check the class order, make sure 5 is on the 2nd column
    print('Class order:',estimator_L1.classes_)
    if estimator_L1.classes_[1] == 5:
        print('Correct positive class selection')
    else:
        print('Incorrect positive class selection, check')
    
    # Calculate AUC_train by applying the estimator on X_train
    Y_train_pred_prob = estimator_L1.predict_proba(X_train)
    Y_train_pred_prob_5star = Y_train_pred_prob[:, 1]
    AUC_train = metrics.roc_auc_score(Y_train, Y_train_pred_prob_5star)
    
    # Calculate AUC_test by applying the estimator on X_test
    Y_test_pred_prob = estimator_L1.predict_proba(X_test)
    Y_test_pred_prob_5star = Y_test_pred_prob[:, 1]
    AUC_test = metrics.roc_auc_score(Y_test, Y_test_pred_prob_5star)
    
    # Calculate fpr and tpr from test data
    fpr, tpr, thresholds = metrics.roc_curve(Y_test, Y_test_pred_prob_5star, pos_label=5)
    
    # Compute complexity by sum of the model coefficients' magnitude
    complexity_coef_sum = np.sum(np.abs(estimator_L1.coef_))
    
    # Compile results
    result_log_L1_list = [c_value, AUC_train, complexity_coef_sum, AUC_test]
    result_log_L1_arr.append(result_log_L1_list)
    result_fpr_L1_arr.append(list(fpr))
    result_tpr_L1_arr.append(list(tpr))
    
    print('C value:',c_value)
    print('Model Complexity:',complexity_coef_sum)
    print('Train_AUC:', AUC_train)
    print('Test_AUC:', AUC_test,'\n')
    
df_log_L1 = pd.DataFrame(result_log_L1_arr,columns=col_labels)
df_log_L1

# %%
estimator_L1_best = linear_model.LogisticRegression(solver = 'liblinear', max_iter=1000, random_state=2022, C=0.1,penalty='l1') 
estimator_L1_best.fit(X_train, Y_train)

# Obtain the features and their magnitude, then sorted by magnitide
df_L1_features = pd.DataFrame(data = {'Coefficient':estimator_L1_best.coef_.tolist()[0],'Feature_Name':vectorizer.get_feature_names_out()})
df_L1_features['Coefficient_Magnitude'] = abs(df_L1_features['Coefficient'])
df_L1_features.sort_values(by='Coefficient_Magnitude', ascending=False).head(10)
